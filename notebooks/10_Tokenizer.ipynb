# %%
# Fetch Clean data
## If you are using the data by mounting the google drive, use the following :
from google.colab import drive
drive.mount('/content/gdrive',  force_remount=False)

# %cd /content/gdrive/MyDrive/FinalThesis/Bitcoin_Datasets/
# Out:
# Mounted at /content/gdrive
# /content/gdrive/MyDrive/FinalThesis/Bitcoin_Datasets

# %%
import pandas as pd
tweet_clean = pd.read_csv("clean_data_06-01-2024.csv")

# %%
# !pip install transformers

# %%
#import torch
#from torch.utils.data.dataset import Dataset
import scipy
#from transformers import pipeline
#from transformers import AutoTokenizer, AutoModelForSequenceClassification
from transformers import BertTokenizer, BertForSequenceClassification, AdamW, BertConfig

# %%
finbert_tokenizer = BertTokenizer.from_pretrained("ProsusAI/finbert")
finbert_model = BertForSequenceClassification.from_pretrained("ProsusAI/finbert")
# Out:
# tokenizer_config.json:   0%|          | 0.00/252 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/758 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]

# %%
tweet_clean.head(30)
# Out:
#                    date                                         clean_text
# 0   2021-02-10 23:59:04  blue ridge bank shares halted nyse bitcoin atm...
# 1   2021-02-10 23:58:48  today thats thursday take friend btc wallet se...
# 2   2021-02-10 23:54:48    guys evening read article btc would like share
# 3   2021-02-10 23:54:33  btc big chance billion price bitcoin fx btc cr...
# 4   2021-02-10 23:54:06  network secured nodes today soon biggest bears...
# 5   2021-02-10 23:53:30  trade crypto binance enjoy cashback trading fe...
# 6   2021-02-10 23:53:17                ltfire amp mangt bitcoin crypto btc
# 7   2021-02-10 23:52:42                     prices update eur btc eth xrp
# 8   2021-02-10 23:52:25  btc bitcoin ethereum eth crypto cryptotrading ...
# 9   2021-02-10 23:52:08   bitcoin investment revolutionary crypto firms...
# 10  2021-02-10 23:52:04           annnd btc bitcoin headed even higher now
# 11  2021-02-10 23:51:25                    prices update usdt btc eth xrp
# ...

# %%
sample = 'btc buying pressure alert price trading around bitcoin crypto'
encoding = finbert_tokenizer.encode(sample)
print('------Finbert Tokenizer------')
print(encoding)
print(finbert_tokenizer.convert_ids_to_tokens(encoding))
# Out:
# ------Finbert Tokenizer------
# [101, 18411, 2278, 9343, 3778, 9499, 3976, 6202, 2105, 2978, 3597, 2378, 19888, 2080, 102]
# ['[CLS]', 'bt', '##c', 'buying', 'pressure', 'alert', 'price', 'trading', 'around', 'bit', '##co', '##in', 'crypt', '##o', '[SEP]']

# %%
finbert_tokenizer.encode??

# %%
from transformers import RobertaTokenizer, RobertaForSequenceClassification, AdamW, RobertaConfig

# %%
roberta_tokenizer = RobertaTokenizer.from_pretrained("cardiffnlp/twitter-roberta-base-sentiment-latest")
# Out:
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/929 [00:00<?, ?B/s]

# %%
sample = 'btc buying pressure alert price trading around bitcoin crypto'
encoding = roberta_tokenizer.encode(sample)
print('------Twitter RoBERTa Tokenizer------')
print(encoding)
print(roberta_tokenizer.convert_ids_to_tokens(encoding))
# Out:
# ------Twitter RoBERTa Tokenizer------
# [0, 25933, 438, 2159, 1164, 5439, 425, 1446, 198, 11388, 21416, 2]
# ['<s>', 'bt', 'c', 'Ġbuying', 'Ġpressure', 'Ġalert', 'Ġprice', 'Ġtrading', 'Ġaround', 'Ġbitcoin', 'Ġcrypto', '</s>']
